# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Dữ liệu
x = ["VBPL + 128 LSTM", "VBPL + 250 LSTM", "TVPL + 250 LSTM", "VBPL + 256 LSTM"]
y_train = [92.96, 94.22, 92.84, 94.13]
y_val = [90.21, 91.79, 91.98, 91.19]
y_test = [90.82, 92.19, 92.02, 91.92]

# Tạo biểu đồ
plt.figure(figsize=(14, 6))

# Vẽ cột cho tập train
plt.bar(x, y_train, label='Train Accuracy', color='#0000CC', width=0.2)

# Vẽ cột cho tập validation
plt.bar([i + 0.2 for i in range(len(x))], y_val, label='Validation Accuracy', color='#009900', width=0.2)

# Vẽ cột cho tập test
plt.bar([i + 0.4 for i in range(len(x))], y_test, label='Test Accuracy', color='#CC0000', width=0.2)

# Hiển thị số trên đầu mỗi cột
for i, value in enumerate(y_train):
    plt.annotate(f"{value:.2f}%", xy=(i, value + 0.2), ha='center', va='bottom', fontsize=12)

for i, value in enumerate(y_val):
    plt.annotate(f"{value:.2f}%", xy=(i + 0.2, value + 0.2), ha='center', va='bottom', fontsize=12)

for i, value in enumerate(y_test):
    plt.annotate(f"{value:.2f}%", xy=(i + 0.4, value + 0.2), ha='center', va='bottom', fontsize=12)

# Thêm nhãn và chú thích
plt.ylabel('Độ chính xác (%)')
plt.ylim(80,100)
plt.title('Độ chính xác của mô hình trên tập Train, Validation và Test trong các trường hợp', fontsize=18)
plt.xticks([i + 0.2 for i in range(len(x))], x, rotation=0)

labels = ['Train Accuracy', 'Validation Accuracy', 'Test Accuracy']
handles = [plt.plot([], color=c)[0] for c in ['#0000CC', '#009900', '#CC0000']]
plt.figlegend(handles, labels, loc='upper left', prop={'size': 12})

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
# Dữ liệu
x = ["VBPL + 128 LSTM", "VBPL + 250 LSTM", "TVPL + 250 LSTM", "VBPL + 256 LSTM"]
y_precision = [0.725, 0.764, 0.836, 0.786]
y_recall = [0.696, 0.709, 0.728, 0.665]
y_f1score = [0.692, 0.727, 0.767, 0.707]

# Tạo biểu đồ
plt.figure(figsize=(10, 6))

# Vẽ cột cho tập train
plt.bar(x, y_precision, label='Precision', color='#0000CC', width=0.2)

# Vẽ cột cho tập validation
plt.bar([i + 0.2 for i in range(len(x))], y_recall, label='Re-call', color='#009900', width=0.2)

# Vẽ cột cho tập test
plt.bar([i + 0.4 for i in range(len(x))], y_f1score, label='F1-score', color='#CC0000', width=0.2)

# Hiển thị số trên đầu mỗi cột
for i, value in enumerate(y_precision):
    plt.annotate(f"{value:.2f}", xy=(i, value), ha='center', va='bottom', fontsize=12)

for i, value in enumerate(y_recall):
    plt.annotate(f"{value:.2f}", xy=(i + 0.2, value), ha='center', va='bottom', fontsize=12)

for i, value in enumerate(y_f1score):
    plt.annotate(f"{value:.2f}", xy=(i + 0.4, value), ha='center', va='bottom', fontsize=12)

# Cài đặt giới hạn trục y từ 0 đến 1
plt.ylim(0.5, 1)

# Thêm nhãn và chú thích
plt.title('Biểu đồ Precision, Re-call và F1-score của mô hình trong các trường hợp', fontsize=14)
plt.xticks([i + 0.2 for i in range(len(x))], x, rotation=0)

labels = ['Precision', 'Re-call', 'F1-score']
handles = [plt.plot([], color=c)[0] for c in ['#0000CC', '#009900', '#CC0000']]
plt.figlegend(handles, labels, loc='upper left', prop={'size': 12})

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import itertools


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1, keepdims = True)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label', va='top')
    plt.show()

# %%
dt =[
    [ 219,   15,    1,    1,   33,   12,   10],
    [  11, 3239,    2,    0,   80,    2,    6],
    [   0,    8,   16,    1,   25,    0,    0],
    [   2,    5,    0,   77,   15,    5,    1],
    [   6,  100,   13,    4, 4503,   12,   20],
    [   9,   12,    0,    0,   58,  213,    8],
    [  16,   28,    0,    3,  191,   17,   64],
]

dt = np.array(dt)

# Plot non-normalized confusion matrix
class_names = ['BTT','CC','DHD','DSD','DC','HHL','None']
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(dt, classes=class_names, normalize=True)

# %%
data = [
    [222, 3, 0, 0, 9, 57, 0],
    [39, 3132, 1, 2, 94, 33, 39],
    [1, 4, 22, 1, 22, 0, 0],
    [2, 1, 0, 80, 9, 7, 6],
    [30, 59, 5, 8, 4496, 60, 27],
    [9, 3, 0, 3, 17, 265, 3],
    [26, 12, 1, 7, 207, 25, 41],
]
data = np.array(data)

# Plot non-normalized confusion matrix
class_names = ['BTT','CC','DHD','DSD','DC','HHL','None']
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(data, classes=class_names, normalize=True)

# %%
data = [
    [ 252,    8,    1,    3,   14,   10,    3],
    [  20, 3226,    4,    1,   69,    4,   16],
    [   0,    7,   22,    1,   20,    0,    0],
    [   1,    4,    1,   71,   10,    8,   10],
    [  18,   92,    8,    6, 4463,   29,   42],
    [   8,   11,    1,    0,   29,  249,    2],
    [  19,   22,    2,    3,  175,   25,   73]
]
data = np.array(data)

# Plot non-normalized confusion matrix
class_names = ['BTT','CC','DHD','DSD','DC','HHL','None']
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(data, classes=class_names, normalize=True)

# %%
data = [
    [   32,     2,    11,     8,    20,     1,    17],
    [    0,  7191,   131,    27,    24,     0,    27],
    [    0,   127, 12521,    35,    97,     7,   535],
    [    3,   100,   108,   170,    17,     0,     4],
    [    5,    10,   109,     3,   753,     0,    68],
    [    0,     0,    18,     1,     6,   230,    64],
    [    5,    44,   661,     9,    51,    17,  6443]
]

data = np.array(data)

# Plot non-normalized confusion matrix
class_names = ['BTT','CC','DC','DHD','DSD','HHL','None']
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(data, classes=class_names, normalize=True)
